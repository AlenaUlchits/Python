# %%
import pandas as pd
import random
import seaborn as s
import matplotlib.pyplot as  mpy

# %%
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  human
# 3  robot
# 4  human

# %%
data.loc[data['whoAmI'] == 'robot', 'robot'] = 1
data.loc[data['whoAmI'] != 'robot', 'robot'] = 0

data.loc[data['whoAmI'] == 'human', 'human'] = 1
data.loc[data['whoAmI'] != 'human', 'human'] = 0

data[['robot', 'human']].head(4)
# Out:
#    robot  human
# 0    1.0    0.0
# 1    0.0    1.0
# 2    0.0    1.0
# 3    1.0    0.0
